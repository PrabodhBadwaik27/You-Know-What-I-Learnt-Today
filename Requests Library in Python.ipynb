# %% [markdown]
# # Requests Library

# %%
import requests
import pandas as pd

# %%
r_get = requests.get('https://api.github.com/events')

# %%
r_get.text
# Out:
# '[{"id":"18015267014","type":"PushEvent","actor":{"id":12084677,"login":"martijn-heil","display_login":"martijn-heil","gravatar_id":"","url":"https://api.github.com/users/martijn-heil","avatar_url":"https://avatars.githubusercontent.com/u/12084677?"},"repo":{"id":135597119,"name":"martijn-heil/9front","url":"https://api.github.com/repos/martijn-heil/9front"},"payload":{"push_id":7948681256,"size":0,"distinct_size":0,"ref":"refs/heads/master","head":"32f37b5c7763451bf9b4979cccab817bfa5453ce","before":"32f37b5c7763451bf9b4979cccab817bfa5453ce","commits":[]},"public":true,"created_at":"2021-09-16T13:18:31Z"},{"id":"18015266996","type":"PushEvent","actor":{"id":29139614,"login":"renovate[bot]","display_login":"renovate","gravatar_id":"","url":"https://api.github.com/users/renovate[bot]","avatar_url":"https://avatars.githubusercontent.com/u/29139614?"},"repo":{"id":282480387,"name":"uhthomas/6f.io","url":"https://api.github.com/repos/uhthomas/6f.io"},"payload":{"push_id":7948681242,"size"
# ...

# %%
r_get.json() =
# Out:
# [{'id': '18015053522',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 10810283,
#    'login': 'direwolf-github',
#    'display_login': 'direwolf-github',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/direwolf-github',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10810283?'},
#   'repo': {'id': 407167988,
#    'name': 'direwolf-github/ephemeral-ci-d19894cb',
#    'url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-d19894cb'},
#   'payload': {'action': 'closed',
#    'number': 1,
#    'pull_request': {'url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-d19894cb/pulls/1',
#     'id': 735458383,
#     'node_id': 'PR_kwDOGETj9M4r1jRP',
#     'html_url': 'https://github.com/direwolf-github/ephemeral-ci-d19894cb/pull/1',
#     'diff_url': 'https://github.com/direwolf-github/ephemeral-ci-d19894cb/pull/1.diff',
#     'patch_url': 'https://github.com/direwolf-github/ephemeral-ci-d19894cb/pull/1.patch',
# ...

# %%
r_post = requests.post('https://httpbin.org/post', data={'key': ['value1', 'value2']})

# %%
r_post.json()
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': ['value1', 'value2']},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '21',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0',
#   'X-Amzn-Trace-Id': 'Root=1-614343fc-4bed669d768a396b4c097306'},
#  'json': None,
#  'origin': '152.57.95.80',
#  'url': 'https://httpbin.org/post'}

# %%
r_post2 = requests.post('https://httpbin.org/post', "Hello", args=[1,2,3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-15a5be29a358> in <module>
# ----> 1 r_post2 = requests.post('https://httpbin.org/post', "Hello", args=[1,2,3])
#
# ~\anaconda3\lib\site-packages\requests\api.py in post(url, data, json, **kwargs)
#     114     """
#     115
# --> 116     return request('post', url, data=data, json=json, **kwargs)
#     117
#     118
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# TypeError: request() got an unexpected keyword argument 'args'

# %%
r_post2.status_code
# Out:
# 200

# %%
r_post2.raise_for_status()
print(r_post2)
# Out:
# <Response [200]>

# %%
r_post2.json()
# Out:
# {'args': {},
#  'data': 'Hello',
#  'files': {},
#  'form': {},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '5',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0',
#   'X-Amzn-Trace-Id': 'Root=1-614346ff-278702fe20b8875a04806440'},
#  'json': None,
#  'origin': '152.57.95.80',
#  'url': 'https://httpbin.org/post'}

# %%
r_put = requests.put('https://httpbin.org/put', data={'key': ''})
r_put.json()
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': ''},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '4',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0',
#   'X-Amzn-Trace-Id': 'Root=1-61434429-2a15cea76d6cb4ee413bf5e4'},
#  'json': None,
#  'origin': '152.57.95.80',
#  'url': 'https://httpbin.org/put'}

# %%
r = requests.put('https://httpbin.org/put', data={'key': ''})
print(r)
r = requests.delete('https://httpbin.org/delete')
print(r)
r = requests.head('https://httpbin.org/get')
print(r)
r = requests.options('https://httpbin.org/get')
print(r)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
r_put.status_code
# Out:
# 200

# %%
r_post.raise_for_status()

# %%
r.history
# Out:
# []

# %%
r.url
# Out:
# 'https://httpbin.org/get'
